# %% [markdown]
# <a href="https://colab.research.google.com/github/kim-woo-joon/AIproject/blob/main/%EA%B0%9C%EB%B0%9C%EC%9E%90%EB%A5%BC_%EC%9C%84%ED%95%9C_%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D_%EB%94%A5%EB%9F%AC%EB%8B%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.9.2

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

model = Sequential([Dense(units = 1, input_shape = [1])])
model.compile(optimizer = 'sgd', loss = 'mean_squared_error')

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype = float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype = float)

model.fit(xs, ys, epochs = 500)

print(model.predict([10.0]))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 483ms/step - loss: 53.0422
# Epoch 2/500
# 1/1 [==============================] - 0s 9ms/step - loss: 42.1366
# Epoch 3/500
# 1/1 [==============================] - 0s 7ms/step - loss: 33.5483
# Epoch 4/500
# 1/1 [==============================] - 0s 8ms/step - loss: 26.7832
# Epoch 5/500
# 1/1 [==============================] - 0s 8ms/step - loss: 21.4528
# Epoch 6/500
# 1/1 [==============================] - 0s 8ms/step - loss: 17.2513
# Epoch 7/500
# 1/1 [==============================] - 0s 12ms/step - loss: 13.9380
# Epoch 8/500
# 1/1 [==============================] - 0s 6ms/step - loss: 11.3238
# Epoch 9/500
# 1/1 [==============================] - 0s 6ms/step - loss: 9.2598
# Epoch 10/500
# 1/1 [==============================] - 0s 6ms/step - loss: 7.6286
# Epoch 11/500
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3383
# Epoch 12/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.3162
# ...

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

dense = Dense(units = 1, input_shape = [1])
model = Sequential([dense])
model.compile(optimizer = 'sgd', loss = 'mean_squared_error')

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype = float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype = float)

model.fit(xs, ys, epochs = 500)

print(model.predict([10.0]))
print("신경망이 학습한것 : {}".format(dense.get_weights()))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 257ms/step - loss: 6.3794
# Epoch 2/500
# 1/1 [==============================] - 0s 10ms/step - loss: 5.2047
# Epoch 3/500
# 1/1 [==============================] - 0s 7ms/step - loss: 4.2768
# Epoch 4/500
# 1/1 [==============================] - 0s 14ms/step - loss: 3.5429
# Epoch 5/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.9620
# Epoch 6/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.5013
# Epoch 7/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.1353
# Epoch 8/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.8440
# Epoch 9/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.6114
# Epoch 10/500
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4251
# Epoch 11/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2753
# Epoch 12/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1543
# ...
